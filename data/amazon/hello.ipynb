# %%
import pandas as pd
from mpmath import lu_solve

# %%
lux = pd.read_json('Luxury_Beauty.json', lines=True)

# lux.head(50)
# Out:
#     overall  vote  verified   reviewTime      reviewerID        asin  \
# 0         5  None      True  01 20, 2016  A37U6JI42ZSTVX  B0084GVSWG
# 1         5  None      True   05 7, 2014  A1OED4I1OI70ZO  B00176GSEI
# 2         4     3      True   08 1, 2016   A2MVXY9W85MC3  B01DU3WXZS
# 3         5  None      True  12 18, 2016  A183Z9HXYX7YG2  B01CNVYGN0
# 4         3     9      True  07 19, 2014  A3QPIBRNYGVKLT  B00ALHISAQ
# 5         3  None      True  04 19, 2018  A19TM9PZK0JIPV  B000BGRC18
# 6         5  None      True  03 11, 2012  A19B4I5716TVEB  B001AO0WCG
# 7         1  None      True  08 30, 2015  A1F91CX7PKCOI6  B000YJ3UEK
# 8         5  None      True  02 19, 2018  A2PWF6C3B3L1A0  B00396OTJ0
# 9         5  None      True   06 7, 2018  A3N7TYFLOEDE74  B00K3Y3V0Y
# 10        5  None      True   12 2, 2014   A2A5ZTDTC0VNI  B00846H9WY
# 11        5  None      True  03 20, 2015   ADD1UHOFADJ74  B00B27040G
# 12        5  None      True  01 18, 2018  A2NVX1ZXFY3KFU  B00RM4QZQK
# ...

# %%
import pandas as pd
import pickle

with open('Luxury_Beauty_text_name_dict.json.gz', 'rb') as f:
    meta = pickle.load(f)

TenNameDict = pd.DataFrame(meta)

TenNameDict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 1 to 72
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        72 non-null     object
#  1   description  72 non-null     object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
import pandas as pd
import pickle

with open('20_Luxury_Beauty_text_name_dict.json.gz', 'rb') as f:
    meta = pickle.load(f)

TwenNameDict = pd.DataFrame(meta)

TwenNameDict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2007 entries, 1 to 2007
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        2007 non-null   object
#  1   description  2007 non-null   object
# dtypes: object(2)
# memory usage: 47.0+ KB

# %%
# lux.head(50)
import pandas as pd
import pickle

TenMeta = pd.read_json('meta_Luxury_Beauty.json', lines=True)
TenMeta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230 entries, 0 to 1229
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   category         1230 non-null   object
#  1   tech1            1230 non-null   object
#  2   description      1230 non-null   object
#  3   fit              1230 non-null   object
#  4   title            1230 non-null   object
#  5   also_buy         1230 non-null   object
#  6   tech2            1230 non-null   object
#  7   brand            1230 non-null   object
#  8   feature          1230 non-null   object
#  9   rank             1230 non-null   object
#  10  also_view        1230 non-null   object
#  11  details          1230 non-null   object
#  12  main_cat         1230 non-null   object
#  13  similar_item     1230 non-null   object
#  14  date             0 non-null      datetime64[ns]
#  15  price            1230 non-null   object
# ...

# %%
TwenMeta = pd.read_json('20_meta_Luxury_Beauty.json', lines=True)
TwenMeta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12299 entries, 0 to 12298
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   category         12299 non-null  object
#  1   tech1            12299 non-null  object
#  2   description      12299 non-null  object
#  3   fit              12299 non-null  object
#  4   title            12299 non-null  object
#  5   also_buy         12299 non-null  object
#  6   tech2            12299 non-null  object
#  7   brand            12299 non-null  object
#  8   feature          12299 non-null  object
#  9   rank             12299 non-null  object
#  10  also_view        12299 non-null  object
#  11  details          12299 non-null  object
#  12  main_cat         12299 non-null  object
#  13  similar_item     12299 non-null  object
#  14  date             0 non-null      datetime64[ns]
#  15  price            12299 non-null  object
# ...

# %%
Lux = pd.read_json('Luxury_Beauty.json.gz', lines=True)
Lux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114927 entries, 0 to 114926
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   overall         114927 non-null  int64
#  1   vote            20690 non-null   object
#  2   verified        114927 non-null  bool
#  3   reviewTime      114927 non-null  object
#  4   reviewerID      114927 non-null  object
#  5   asin            114927 non-null  object
#  6   reviewerName    114921 non-null  object
#  7   reviewText      114846 non-null  object
#  8   summary         114891 non-null  object
#  9   unixReviewTime  114927 non-null  int64
#  10  style           50267 non-null   object
#  11  image           1491 non-null    object
# dtypes: bool(1), int64(2), object(9)
# memory usage: 9.8+ MB
